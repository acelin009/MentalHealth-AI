# %% [markdown]
# # 🧠 Mental Health Intelligence Platform
#
# ## Phase 4 — Exploratory Data Analysis
#
#
# ### Overview
#
# After completing the data cleaning and harmonization phases, the dataset is now ready for exploratory analysis.
#
# The objective of this notebook is to provide a high-level understanding of the unified OSMI Mental Health Survey dataset before performing detailed analyses.
#
# The notebook summarizes the overall composition of the dataset and highlights key characteristics that will guide subsequent analyses.
#
# ---
#
# ### Objectives
#
# The primary objectives are:
#
# - Understand the overall structure of the harmonized dataset
# - Summarize the respondent population
# - Explore survey coverage across multiple years
# - Review missing values
# - Establish baseline statistics for later analyses

# %% [markdown]
# ## Import Required Libraries

# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go

pd.set_option("display.max_columns", None)

print("Libraries Imported Successfully")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 7
#       3
#       4 import pandas as pd
#       5 import numpy as np
#       6
# ----> 7 import plotly.express as px
#       8 import plotly.graph_objects as go
#       9
#      10 pd.set_option("display.max_columns", None)
#
# ModuleNotFoundError: No module named 'plotly'
